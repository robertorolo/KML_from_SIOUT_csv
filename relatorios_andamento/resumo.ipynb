# %%
import matplotlib.pyplot as plt

# %%
labels = ['janeiro', 'fevereiro', 'março', 'abril', 'maio', 'junho']
x = [1, 2, 3, 4, 5, 6]
total = [49, 78, 81, 81, 81, 94]
aguardando = [31, 28, 27, 7, 7, 2]
em_analise = [4, 9, 10, 1, 0, 2]
indeferida = [3, 13, 13, 13, 15, 15]
concedida = [5, 6, 9, 20, 32, 35]
alteracao = [6, 22, 22, 40, 27, 40]

# %%
plt.figure(figsize=(10, 7))
#plt.plot(x, total, label='Total')
plt.plot(x, aguardando, label='Aguardando análise')
plt.plot(x, em_analise, label='Em análise')
#plt.plot(x, indeferida, label='Indeferido', color='red')
plt.plot(x, concedida, label='Concedida', color='green')
plt.plot(x, alteracao, label='Aguardando correção', color='gray')
plt.xticks(x,labels)
plt.legend(loc='upper left')
plt.savefig('resumo.png')

# %%
((total[-1]-total[0])/total[0]) * 100
# Out:
# 91.83673469387756

# %%
((concedida[-1]-concedida[0])/concedida[0]) * 100
# Out:
# 600.0

# %%
((aguardando[-1]-aguardando[0])/aguardando[0]) * 100
# Out:
# -93.54838709677419

# %%
(5*30+5)/35
# Out:
# 4.428571428571429

# %%
import pandas as pd

# %%
nomes = pd.read_csv('nomes.csv')

# %%
nomes['Nome'][0].split()
# Out:
# ['PCH', 'Sede', 'II']

# %%
tipo = [i.split()[0] for i in nomes['Nome']]

# %%
import numpy as np

# %%
tipo = np.array(tipo)

# %%
pie_dict = {}
for s in tipo:
    ns = sum(tipo == s)
    pie_dict[s] = ns

# %%
pie_dict
# Out:
# {'PCH': 31, 'CGH': 68, 'UHE': 2}

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %%
plt.figure(figsize=(10,10))
plt.pie(pie_dict.values(), autopct=make_autopct(pie_dict.values()), labels=pie_dict.keys())
plt.savefig('tipo.png')
